# %% [markdown]
# #  **Exploratory Data Analysis on Titanic Dataset**

# %% [markdown]
# **Author**: Yasmeen Rafique | Data Analytics Enthusiast
# 📅 July 2025 | 📍 Pakistan

# %% [markdown]
# ### 📌 Introduction
# This project dives into the Titanic dataset to explore survival patterns using Python. We'll analyze how variables like age, class, and gender affected survival rates, and cover key trends with visualizations.

# %% [markdown]
# ### 🎯 Objective
# - Perform EDA (Exploratory Data Analysis)
# - Identify key survival factors
# - Visualize patterns using Seaborn & Matplotlib

# %% [markdown]
# ### 📂 Dataset Description
# The dataset contains info about Titanic passengers:
# - `Survived`, `Pclass`, `Sex`, `Age`, `Fare`, etc.

# %% [markdown]
# ### ⚙️ Tools & Libraries
# - Python
# - Pandas
# - Matplotlib, Seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h4 align='center'><b>Basic Data Exploration</b></h4>

# %%
data = sns.load_dataset("titanic")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.shape
# Out:
# (891, 15)

# %% [markdown]
# <h4 align='center'><b>Data Cleaning</b></h4>

# %%
print(data.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Fill missing Age with median
data['age'] = data['age'].fillna(data['age'].median())

# %%
# Fill Embarked with mode
data['embarked'] = data['embarked'].fillna(data['embarked'].mode())

# %%
# Drop Deck (too many missing values)
data.drop(columns=['deck'], inplace=True)

# %%
# Fill embark_town with mode
data['embark_town'].fillna(data['embark_town'].mode())
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# #### datatype conversion

# %%
data['sex'] = data['sex'].astype('category')
type('sex')
# Out:
# str

# %%
data['embarked'] = data['embarked'].astype('category')
type('embarked')
# Out:
# str

# %% [markdown]
# <h4 align = 'center'><b>Summary Statistics and Group Analysis</b></h4>

# %%
# Survival rate by gender
print(data.groupby('sex')['survived'].mean())
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64
# C:\Users\E5400\AppData\Local\Temp\ipykernel_2944\319726543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(data.groupby('sex')['survived'].mean())

# %%
# Survival rate by class
print(data.groupby('pclass')['survived'].mean())
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %% [markdown]
# <h4 align='center'><b>Visualization</b></h4>

# %% [markdown]
# #### survival gender wise

# %%
sns.barplot(x='sex',y='survived',data=data,color='g')
plt.title('Survival Rate by Gender')
plt.show()

# %% [markdown]
# #### **survival class wise**

# %%
sns.barplot(x='pclass',y='survived',data=data,color='y')
plt.title('Survival Rate by class')
plt.show()

# %% [markdown]
# #### **Age distribution by survival**

# %%
sns.histplot(data=data,x='age',hue='survived',multiple='stack',kde=True,palette='Set1')
plt.title('Age distribution by survival')
plt.show()

# %% [markdown]
# #### **Feature correlation**

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.title('Feature Correlation')
plt.show()

# %% [markdown]
# ### **Insights:**

# %% [markdown]
# ##### **Gender and Survival**:
# Females had a significantly higher survival rate than males.\
# Most women and children were prioritized during evacuation.
# ##### **Passenger Class**:
# Passengers in 1st class had the highest survival rate.\
# 3rd class passengers had the lowest chance of survival.
# ##### **Age Distribution**:
# Children under 10 had relatively high survival rates.\
# Elderly passengers had lower survival chances.
# ##### **Fare**:
# Survivors tended to have paid higher fares on average.\
# Indicates wealth or class was a key survival factor.
# ##### **Embarkation Port**:
# Most passengers boarded from Southampton (S).\
# Survival rates varied slightly based on embarkation location.

# %% [markdown]
# ### **Conclusion**:
# Survival on the Titanic was influenced heavily by gender, class, and age. Females, especially in first class, were far more likely to survive than males or passengers in lower classes.

# %% [markdown]
# ---
#
# ## 🙋‍♀️ About Me
#
# I'm Yasmeen Rafique, a Data Analytics passionate about storytelling with data, automation, and building impactful things in data field.
# Connect with me on [LinkedIn](www.linkedin.com/in/yasmeen-rafique) or check out more projects on [GitHub](https://github.com/Yasmeenrafique).
